# %% [markdown]
# <a href="https://colab.research.google.com/github/EndarMuh/PCVK_Ganjil_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
# Baca dan tampilkan image
# Loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **PERTANYAAN**

# %% [markdown]
# 1.   Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
# 2.   Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# 3.  Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
# ```
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# ```
#   Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# 4.  Perhatikan potongan kode program berikut :
#
#
# ```
# #membuat garis horizontal ditengah image
# for y in range (lebar) :
#   image_3[int((tinggi)/2),y] = [255,255,255]
# ```
#
#   Apakah kegunaan kode [255,255,255]? Jelaskan!
# 5.  Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
#
#
# **Jawaban**
# 1.  Dikarenakan akses nya cukup mudah, tidak perlu spek yang tinggi, serta bisa terhubung dengan github si pengguna
#
# 2.  - Numpy       = Fungsinya menyediakan struktur data array multidimensi yang efisien serta untuk operasi pada array.
#     - Pandas      = Fungsinya digunakan analisis dan manipulasi data.
#     - CV2         = Fungsinya untuk pengolahan gambar dan penglihatan komputer, memberikan berbagai fungsi untuk manipulasi gambar, deteksi objek, pelacakan, segmentasi dan pengolahan gambar lainnya.
#     - Skimage     = Fungsinya untuk pengolahan gambar yang berfokus pada analisis ilmiah dari berbagai format.
#     - Matplotlib  = Fungsinya untuk mengvisualisasikan seperti grafik garis, histogram dll. Memungkinkan untuk membuat visualisasi yang estetis dan informatif.
#
# 3.  Jadi, kode ini mengubah ukuran gambar menjadi setengah ukuran aslinya baik secara horizontal maupun vertikal, karena fx dan fy diberikan nilai 0.5.
#
# 4.  Merupakan kode warna putih.
#
# 5.  Keterikatan nya yaitu pixel dan resolusi gambar saling terkait karena pixel adalah elemen dasar yang membentuk gambar, dan resolusi gambar mengukur jumlah total pixel dalam gambar. Resolusi tinggi memberikan lebih banyak detail, sementara resolusi rendah menghasilkan gambar yang lebih kasar dengan ukuran file yang lebih kecil.

# %% [markdown]
# **TUGAS**

# %% [markdown]
# 1.   Lakukanlah langkah-langkah praktikum seperti diatas
# 2.   Buat garis vertikal dan garis menyilang diagonal pada image keluaran
# 3.  Buat garis horizontal berwarna putih dibagian tengah gambar dengan panjang tertentu
# 4.  Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar

# %% [markdown]
# **NO 2**

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis vertikal ditengah image
for x in range (min(tinggi, lebar)):
  image_3[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis diagonal menyilang ditengah image
for z in range (lebar):
  i = int(z * (tinggi / lebar))
  image_3[i, z] = [255,255,255]
  image_3[i, lebar - z - 1] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **NO 3**

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis horizontal putih ditengah image dengan ukuran tertentu

panjang_garis = 80

x1 = int(lebar / 2 - panjang_garis / 2)
x2 = int(lebar / 2 + panjang_garis / 2)
y = int(tinggi / 2)

cv.line(image_3, (x1, y), (x2, y), (255, 255, 255), 2)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **NO 4**

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis horizontal putih ditengah image dengan ukuran tertentu
ukuran_kotak = 120

x1 = int(lebar / 2 - ukuran_kotak / 2)
x2 = int(lebar / 2 + ukuran_kotak / 2)
y1 = int(tinggi / 2 - ukuran_kotak / 2)
y2 = int(tinggi / 2 + ukuran_kotak / 2)

cv.rectangle(image_3, (x1, y1), (x2, y2), (255, 255, 255), -1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **TUGAS KELOMPOK 3**
#
# Tutup bagian Gol. Darah dan TTD
#
# Anggota :
# - Ahmad Bima Tristan Ibrahim      (1)
# - Arsyanda Irza Rabbani Yuardhino (6)
# - Muhammad Endar Darmawan         (21)

# %%
import cv2 as cv
import matplotlib.pyplot as plty

# Ganti dengan path ke file gambar Anda (KTP/SIM)
path_to_image = ('/content/KTP.png')

# Baca gambar menggunakan OpenCV
image = cv.imread(path_to_image)

# Warna kotak (hitam)
warna_kotak1 = (0, 0, 0)

# Koordinat pojok kiri atas dan kanan bawah kotak
x1 = int(lebar * 1.35)
y1 = int(tinggi * 0.65)
x2 = int(lebar * 0.95) #panjang
y2 = int(tinggi * 0.55)

# Gambar kotak putih pada gambar
cv.rectangle(image, (x1, y1), (x2, y2), warna_kotak1, -1)

# Warna kotak (putih)
warna_kotak2 = (255, 255, 255)

# Koordinat pojok kiri atas dan kanan bawah kotak
x3 = int(lebar * 1.48)
y3 = int(tinggi * 1.37)
x4 = int(lebar * 1.90) #panjang
y4 = int(tinggi * 1.67)

# Gambar kotak putih pada gambar
cv.rectangle(image, (x3, y3), (x4, y4), warna_kotak2, -1)

# Ubah format warna gambar dari BGR menjadi RGB untuk digunakan oleh Matplotlib
image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Tampilkan gambar menggunakan Matplotlib
plt.imshow(image_rgb)
plt.axis('off')  # Tidak menampilkan sumbu koordinat
plt.show()
